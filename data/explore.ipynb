# %%
import pandas as pd

df = pd.read_pickle('math_articles.pd')
df
# Out:
#                                                 article
# 0     {{About|use in [[pharmacology]] and [[medicine...
# 1     {{Refimprove|date=February 2013}}\n{{Programmi...
# 2     '''Sylver coinage''' is a [[mathematical game]...
# 3     {{Redirect|Dependency resolution|other uses|De...
# 4     {{Quantum mechanics|cTopic=Formulations}}\nIn ...
# 5     '''Modular exponentiation''' is a type of [[ex...
# 6     '''Teleparallelism''' (also called '''telepara...
# 7     In [[modular arithmetic]] computation, '''Mont...
# 8     [[File:Split-ring resonator array 10K sq nm.jp...
# 9     {{distinguish|parallel transport}}\n[[Image:Ev...
# 10    In [[category theory]], a '''natural number ob...
# 11    {{Refimprove|date=April 2016}}\n{{For|a ratio ...
# 12    In [[proof theory]], '''proof nets''' are a ge...
# 13    In [[quantum physics]], '''Fermi's golden rule...
# 14    {{Eastern name order|Lomb Kató}}\n'''Kató Lomb...
# 15    In [[mathematics]], specifically in [[homotopy...
# ...
