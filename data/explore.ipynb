# %% [markdown]
# First we read in the math article dataframe

# %%
import pandas as pd
from random import randint

df = pd.read_pickle('math_articles.pd')

# %% [markdown]
# Next, we'll randomly sample 10 articles

# %%
articles = [df.iloc[[randint(0, len(df))]].article.values[0] for i in range(10)]
articles[0].split('.')
# Out:
# ["{{Quantum mechanics|cTopic=Background}}\n\nIn [[quantum mechanics]], '''bra–ket notation''' is a standard notation for describing [[quantum state]]s",
#  ' It can also be used to denote abstract [[vector space|vectors]] and [[linear functional]]s in [[mathematics]]',
#  ' \nThe notation begins with using [[angle bracket]]s, ⟨ and ⟩, and a [[vertical bar]], |, to denote the scalar product of vectors or the action of a linear functional on a vector in a complex vector space',
#  '  The scalar product or action is written as\n\n:<math>\\langle\\phi\\mid\\psi\\rangle',
#  "</math>\n\nThe right part is called the '''ket''' {{IPAc-en|k|ɛ|t}}; it is a [[vector space|vector]], typically represented as a [[column vector]] and written \n\n:<math>|\\psi\\rangle",
#  "</math>\n\nThe left part is called the '''bra''', {{IPAc-en|b|r|ɑː}}; it is the [[Hermitian conjugate]] of the ket with the same label, typically represented as a [[row vector]] and is written\n\n:<math>\\langle\\phi|",
# ...
